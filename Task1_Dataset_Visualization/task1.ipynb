# %%
import seaborn as sns
# Load the Iris dataset directly from seaborn
df = sns.load_dataset('iris')
# Show the first 5 rows
print('First 5 rows:')
df.head()
# Out:
# First 5 rows:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# How many rows and columns?
print('Shape:', df.shape)   # Output: (150, 5)
# What are the column names?
print('Columns:', df.columns.tolist())
# What data types does each column have?
df.info()
# Out:
# Shape: (150, 5)
# Columns: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Get statistical summary (min, max, average, etc.)
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# How many flowers of each species?
df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
# A scatter plot shows the relationship between two measurements. Each dot = one flower.
# Scatter plot: Sepal Length vs Sepal Width
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))   # set chart size
sns.scatterplot(
    data=df,
    x='sepal_length',
    y='sepal_width',
    hue='species',   # color by species
    palette='Set1'
)
plt.title('Sepal Length vs Sepal Width by Species')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.legend(title='Species')
plt.tight_layout()
plt.show()

# %%
# Histograms show how values are distributed — for example, what is the most common petal length?
# Histogram for all 4 measurements
import matplotlib.pyplot as plt
import seaborn as sns
# Ensure 'df' is the pandas DataFrame here, in case it was overwritten or confused
df = sns.load_dataset('iris')
df.drop('species', axis=1).hist(
    bins=20,
    figsize=(10, 6),
    color='steelblue',
    edgecolor='black'
)
plt.suptitle('Distribution of All Features', y=1.02)
plt.tight_layout()
plt.show()

# %%
# Box plots show outliers (unusual values) and the spread of data per species.
# Box plots for each feature grouped by species
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
features = ['sepal_length','sepal_width','petal_length','petal_width']
for i, feature in enumerate(features):
    ax = axes[i//2, i%2]
    sns.boxplot(data=df, x='species', y=feature, palette='pastel', ax=ax)
    ax.set_title(f'Box Plot of {feature}')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_941/426960961.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='species', y=feature, palette='pastel', ax=ax)
# /tmp/ipykernel_941/426960961.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='species', y=feature, palette='pastel', ax=ax)
# /tmp/ipykernel_941/426960961.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='species', y=feature, palette='pastel', ax=ax)
# /tmp/ipykernel_941/426960961.py:7: FutureWarning:
#
# ...

# %% [markdown]
# Task 1: Summary of Findings
#
# * The dataset has 150 rows and 5 columns.
# *  There are 3 species: Setosa, Versicolor, and Virginica.
# *  Setosa has noticeably smaller petals than the other two species.
# *   The scatter plot shows Setosa is clearly separable from the others.
# * No major outliers were found in the box plots.
